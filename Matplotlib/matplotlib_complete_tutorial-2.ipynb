# %%
#Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=5,2 #Reducing size of image, write only once work for all


x1 = np.linspace(0,10,50)

# create a plot figure
# fig = plt.figure()
plt.plot(x1,np.sin(x1), '-')
plt.plot(x1,np.cos(x1), '--')
plt.show()

# %%
# create the first of two panels and set current axis
plt.subplot(2,1,1) # (rows , columns, panel number)
plt.plot(x1,np.cos(x1),'*')

# %%
# create a plot figure

# create the first of two panels and set the current axis
plt.subplot(2,1,1) # (rows , columns, panel number)
plt.plot(x1,np.sin(x1))
# create the second of two panels and set the current axis
plt.subplot(2,1,2) # (rows , columns, panel number)
plt.plot(x1,np.cos(x1))

# %%
# get current figure info
print(plt.gcf())
# get current axis info
print(plt.gca())
# Out:
# Figure(500x200)
# Axes(0.125,0.11;0.775x0.77)

# %%
# Plotting with 2 different lists / arrays

plt.plot([1,2,3,4],[1,8,2,16])
plt.ylabel('Numbers') #Labelling Y - axis as "Numbers"
# Out:
# Text(0, 0.5, 'Numbers')

# %%
plt.plot([1,2,3,4],[9,5,3,21])

# %%
# Graph with Titles and Lables
x=np.linspace(0,2,100)
plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='quadradic')
plt.plot(x,x**3,label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("SIMPLE PLOT")
plt.legend() # To call lables ** MUST USE **

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.axis([0,6,0,20])
# Out:
# (np.float64(0.0), np.float64(6.0), np.float64(0.0), np.float64(20.0))

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0.,5.,0.2)
# red dashes, blue squares and green triangles
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')

# %%
# First create a grid of plots
fig, ax = plt.subplots(2) # ax will be an array of two Axes objects

# Call plot() method on the appropriate object
ax[0].plot(x1,np.sin(x1),'b-')
ax[1].plot(x1,np.cos(x1),'k-')

# %%
fig = plt.figure()
x2=np.linspace(0,5,10)
y2 = x2**2
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x2,y2,'r')
axes.set_xlabel('x2')
axes.set_ylabel('y2')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig = plt.figure()
ax = plt.axes()
plt.plot([1,3,2,4],'b-')

# %%
x3 = np.arange(0.0,6.0,0.01)
plt.plot(x3,[xi**2 for xi in x3],'b-')

# %%
# print 3 different plot lines
x4 = range(1,5)
plt.plot(x4,[xi*1.5 for xi in x4])
plt.plot(x4,[xi*3 for xi in x4])
plt.plot(x4,[xi/3.0 for xi in x4])

# %%
# Saving the figure
fig.savefig('plot1.png')

# %%
# Explore the contents of figure
from IPython.display import Image
Image('plot1.png')

# %%
# Explore Supported file yupes
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %%
# create figure and axis first
fig = plt.figure()
ax = plt.axes()
#Declare a variable
x5 = np.linspace(0,10,100)
#Plot the sin function
ax.plot(x5,np.sin(x5),'b-')

# %%
x7=np.linspace(0,10,30)
y7 = np.sin(x7)
plt.plot(x7,y7,'o',color='black')

# %%
# Bar graph
data1 = np.random.randn(1000)
plt.hist(data1)
# Out:
# (array([ 13.,  48.,  97., 173., 223., 209., 146.,  63.,  23.,   5.]),
#  array([-2.75268724, -2.17524654, -1.59780585, -1.02036515, -0.44292446,
#          0.13451624,  0.71195693,  1.28939762,  1.86683832,  2.44427901,
#          3.02171971]),
#  <BarContainer object of 10 artists>)

# %%
# Bar Graph type 2
data2 = [5.,25.,50.,20.]
plt.bar(range(len(data2)),data2)
# Out:
# <BarContainer object of 4 artists>

# %%
# Bar Graph type 2 --- Horizontal
data2 = [5.,25.,50.,20.]
plt.barh(range(len(data2)),data2)
# Out:
# <BarContainer object of 4 artists>

# %%
x9 = np.arange(0, 4, 0.2)
y9 = np.exp(-x9)
e1 = 0.1 * np.abs(np.random.randn(len(y9)))
plt.errorbar(x9, y9, yerr = e1, fmt = '.-')
plt.show();

# %%
# Coloured Multi Graph
A = [15.,30.,45.,22.]
B = [15.,25.,50.,20.]
z2 = range(4)
plt.bar(z2,A,color='b')
plt.bar(z2,B,color='r',bottom = A) # Colour bottom of A
# Out:
# <BarContainer object of 4 artists>

# %%
# Pie chart
plt.figure(figsize=(7,7))
x10 = [35, 25, 20, 20]
labels = ['Computer', 'Electronics', 'Mechanical', 'Chemical']
plt.pie(x10, labels=labels);
plt.show()

# %%
# Box graph
data3 = np.random.randn(100)
plt.boxplot(data3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x153073750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x153073c50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x153072fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1530739d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x153073890>],
#  'means': []}

# %%
# Create some data
x12 = range(1,6)
y12 = [1,4,6,8,4]

#Area plot
plt.fill_between(x12,y12)

# %%
# Create a matrix
mat = np.random.rand(10,20)
cp = plt.contour(mat)

# %%
# Grid graph
x15 = np.arange(1,5)
plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)
plt.grid(True)

# %%
u = [5, 4, 9, 7, 8, 9, 6, 5, 7, 8]
plt.plot(u)
plt.xticks([2, 4, 6, 8, 10])
plt.yticks([2, 4, 6, 8, 10])
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.xlabel('This is the X axis')
plt.ylabel('This is the Y axis')
plt.show()

# %%
x16 = np.arange(1, 5)
plt.plot(x16, 'r')
plt.plot(x16+1, 'g')
plt.plot(x16+2, 'b')
plt.show()

# %%
x16 = np.arange(1, 5)
plt.plot(x16, '--', x16+1, '-.', x16+2, ':')
plt.show()

# %% [markdown]
# # ADDITIONAL MATPLOTLIB OPERATIONS

# %%
#line plot
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 4))
plt.plot(x, y, label="sin(x)", color='blue')
plt.title("Sine Function")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()

# %%
#bar chat

cities = ['Delhi', 'Mumbai', 'Bangalore', 'Chennai']
population = [18, 20, 12, 8]

plt.figure(figsize=(4,2))
plt.bar(cities, population, color='green')
plt.title("Population of Cities (in millions)")
plt.xlabel("Cities")
plt.ylabel("Population")
plt.show()

# %%
#pie chart
labels = ['Sleep', 'Work', 'Exercise', 'Leisure', 'Others']
sizes = [8, 9, 2, 3, 2]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']

plt.figure(figsize=(3,3))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title("Daily Time Allocation")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#histogarm
scores = np.random.normal(loc=70, scale=10, size=1000)

plt.figure(figsize=(6,4))
plt.hist(scores, bins=30, color='skyblue', edgecolor='black')
plt.title("Exam Score Distribution")
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()
