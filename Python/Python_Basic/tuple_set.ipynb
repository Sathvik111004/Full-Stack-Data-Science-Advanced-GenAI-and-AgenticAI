# %%
tup1 = () #Empty tuple

# %%
tup2 = (10,20,30,40,50) #Int

# %%
tup3 = (10.3,20.2,40.2,55.6) #Float

# %%
tup4 = ('one','two','three') # String

# %%
tup5 = (22,11,'GS',(23,26),('num','int')) #Nested tuple

# %%
tup6 = (31,[50,40],{44,50},'AA') # Mixed DataStructure inside a tuple

# %%
len(tup6)
# Out:
# 4

# %%
tup4[1] #Tuple indexing
# Out:
# 'two'

# %%
tup6[1][0]
# Out:
# 50

# %%
#TUPLE SLICING

# %%
tupl = ('one','two','three','four','five','six')

# %%
tupl[2:]
# Out:
# ('three', 'four', 'five', 'six')

# %%
tupl[-1:]
# Out:
# ('six',)

# %%
tupl[3:5]
# Out:
# ('four', 'five')

# %%
tupl[:] #return whole tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six')

# %%
for i in tupl: #For loop in a tuple
    print(i)
# Out:
# one
# two
# three
# four
# five
# six

# %%
for i in enumerate(tupl):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')

# %%
tupl.index('six') #Indesing in tuple
# Out:
# 5

# %%
tupl2 = (20,21,22,10,3,2,45,14)

# %%
sorted(tupl2) #sorts tuple
# Out:
# [2, 3, 10, 14, 20, 21, 22, 45]

# %%
sorted(tupl2, reverse=2) # sort and reverse the tuple
# Out:
# [45, 22, 21, 20, 14, 10, 3, 2]
