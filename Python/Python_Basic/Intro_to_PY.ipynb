# %%
2e0  #float using exponential
# Out:
# 2.0

# %%
2e1
# Out:
# 20.0

# %%
2e4
# Out:
# 20000.0

# %%
2.5e3
# Out:
# 2500.0

# %%
t = True
f = False

# %%
print(t+f)
print(t-f)
print(t*f)
print(f//t)
# Out:
# 1
# 1
# 0
# 0

# %%
c = 10+80j  #complex example

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
d = 20+10j

# %%
print (c+d)
# Out:
# (30+90j)

# %%
#list

# %%
l = [] # List
len(l)
# Out:
# 0

# %%
l1 = [10,20,30] #DataStrucutre
len(l1)
# Out:
# 3

# %%
# List Functions
l1.append(40)
l1.append(50)
l1.append(6)
l1.append(70)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 6, 70]

# %%
#Nested List - List inside a List
l1.append(['a','b','c'])

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 6, 70, ['a', 'b', 'c']]

# %%
# Mixed Integer
l2 = (33,12.3,'GS',12+2j)
l2
# Out:
# (33, 12.3, 'GS', (12+2j))

# %%
#Type class

print(type(l))
print(type(l2))
print(type(l1))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'list'>

# %%
#List Membership

10 in l1
# Out:
# True

# %%
1000 in l1
# Out:
# False

# %%
['a', 'b', 'c'] in l1
# Out:
# True

# %%
#Copy Function
l3 = l1.copy()

# %%
l3
# Out:
# [10, 20, 30, 40, 50, 6, 70, ['a', 'b', 'c']]

# %%
print(id(l1))
print(id(l3))
# Out:
# 4366749376
# 4366837440

# %%
print((l))
print((l1))
print((l2))
print(l3)
# Out:
# []
# [10, 20, 30, 40, 50, 6, 70, ['a', 'b', 'c']]
# (33, 12.3, 'GS', (12+2j))
# [10, 20, 30, 40, 50, 6, 70, ['a', 'b', 'c']]

# %%
#Clear function

l3.clear()

# %%
len(l3)
# Out:
# 0

# %%
#count function

l1.count(40) # No of times the value has occured
# Out:
# 1

# %%
#Slicing
l1[4:]
# Out:
# [50, 6, 70, ['a', 'b', 'c']]

# %%
l1[6:-1]
# Out:
# [70]

# %%
l1[0:10:3]
# Out:
# [10, 40, 70]

# %%
l1[::1]
# Out:
# [10, 20, 30, 40, 50, 6, 70, ['a', 'b', 'c']]

# %%
l1[::5] # count every 5 steps
# Out:
# [10, 6]

# %%
print(l)
print(l1)
# Out:
# []
# [10, 20, 30, 40, 50, 6, 70, ['a', 'b', 'c']]

# %%
l1[5] = 60 # Changing values---MUTABLE
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, ['a', 'b', 'c']]

# %%
l1[-1] = 80
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]
# (33, 12.3, 'GS', (12+2j))

# %%
l.extend(l2) #Extend Function
l
# Out:
# [33, 12.3, 'GS', (12+2j)]

# %%
print(l)
# Out:
# [33, 12.3, 'GS', (12+2j)]

# %%
l.extend(l1)
l
# Out:
# [33, 12.3, 'GS', (12+2j), 10, 20, 30, 40, 50, 60, 70, 80]

# %%
l.index(12.3) #Index Function
# Finds the idex of elment in the list
# Out:
# 1

# %%
l.index('GS')
# Out:
# 2

# %%
l.index(10) #If multiple occurances, index function print the first occurance
# Out:
# 4

# %%
print(l1)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l1.insert(1,25) #Insert object-- insert(index no,object)
l1
# Out:
# [10, 25, 20, 30, 40, 50, 60, 70, 80]

# %%
l1.pop(1)
# Out:
# 25

# %%
print(l1)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l1.pop() #Remove last value --- pop(index), removes index value
# Out:
# 80

# %%
l1.append(80)

# %%
print(l1)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l1.remove(70) #removes the value required

# %%
print(l1)
# Out:
# [10, 20, 30, 40, 50, 60, 80]

# %%
l1.reverse() # Reverse the List
print(l1)
# Out:
# [80, 60, 50, 40, 30, 20, 10]

# %%
l4 = [30,'GS',10,True,5,20,'NAM','ZACK']
print(l4)
# Out:
# [30, 'GS', 10, True, 5, 20, 'NAM', 'ZACK']

# %%
l4 = [30,10,20,40,5] # Sort the list

# %%
l4.sort() # Ascending sort

# %%
print(l4)
# Out:
# [5, 10, 20, 30, 40]

# %%
l4.sort(reverse=True) #Decending Sort

# %%
print(l4)
# Out:
# [40, 30, 20, 10, 5]

# %%
print(l4)
# Out:
# [40, 30, 20, 10, 5]

# %%
l4 = [30,'GS',10,True,5,20,'NAM','ZACK']
print(l4)
# Out:
# [30, 'GS', 10, True, 5, 20, 'NAM', 'ZACK']

# %%
l4[1][1] #Nested Indexing calling S from GS
# Out:
# 'S'

# %%
for i in enumerate(l4): # Counts the list
    print(i)
# Out:
# (0, 30)
# (1, 'GS')
# (2, 10)
# (3, True)
# (4, 5)
# (5, 20)
# (6, 'NAM')
# (7, 'ZACK')

# %%
l4
# Out:
# [30, 'GS', 10, True, 5, 20, 'NAM', 'ZACK']

# %%
all(l4)
# Out:
# True

# %%
any(l1)
# Out:
# True

# %%
l4.append(0)

# %%
all(l4) # If list contains zero is throws false
# Out:
# False

# %%
any(l4)
# Out:
# True

# %%
t = (10,20,30) #tuple
t
# Out:
# (10, 20, 30)

# %%
t.count(10) # counts occurance of value
# Out:
# 1

# %%
t.index(30) # Idex of the value
# Out:
# 2

# %%
20 in t
# Out:
# True

# %%
t * 3
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
t1=()

# %%
s = {}
s
# Out:
# {}

# %%
type(s) # By default it shows dictionaty
# Out:
# dict

# %%
s1 = {100,60,30,60,11} # Always sorted print
s1
# Out:
# {11, 30, 60, 100}

# %%
type(s1) # No empty set shows set only
# Out:
# set

# %%
s2 = {3,2+3j,5.5,90,60}
s2
# Out:
# {(2+3j), 3, 5.5, 60, 90}

# %%
print(s)
print(s1)
print(s2)
# Out:
# {}
# {11, 100, 60, 30}
# {3, 5.5, 90, (2+3j), 60}

# %%
s1.add(25) # Adds in sorted order
s1
# Out:
# {11, 25, 30, 60, 100}

# %%
s= s2.copy() #Copies another set
s
# Out:
# {(2+3j), 3, 5.5, 60, 90}

# %%
s.clear()  # Clears set
s
# Out:
# set()

# %%
s1.pop()
s1
# Out:
# {11, 25, 30, 60}

# %%
s1.discard(3000) # element is not present, it does not give error
s1
# Out:
# {11, 25, 30, 60}

# %%
s1.remove(3000) # Element is not present, so it throws error
s1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 s1.remove(3000) # Element is not present, so it throws error
#       2 s1
#
# KeyError: 3000

# %%
s1.add(40)
s1.add(30)
s1.add(60)
s1
# Out:
# {11, 25, 30, 40, 60}
