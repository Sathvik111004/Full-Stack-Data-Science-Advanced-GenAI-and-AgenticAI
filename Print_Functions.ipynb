# %%
a=10
b=20
a
b # Prints only latest value...
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)  #Prints all required outputs
# Out:
# 10
# 20

# %%
print(a,b,'Python') #Prints all values with space
# Out:
# 10 20 Python

# %%
add = a + b
print('The sum of',a,'and',b,'is =',add)
# Out:
# The sum of 10 and 20 is = 30

# %%
print('The addition of {} and {} is = {}'.format(a,b,add)) #Using format method
# Out:
# The addition of 10 and 20 is = 30

# %%
num1 = 60
num2 = 70
num3 = 90
avg=(num1+num2+num3)/3
avg1=round((num1+num2+num3)/3,2) #Only 2 decimal values
print('The avrage of {}, {}, and {} is= {} or {}'.format(num1,num2,num3,avg,avg1))
# Out:
# The avrage of 60, 70, and 90 is= 73.33333333333333 or 73.33

# %%
print(f'the avg of {num1},{num2} and {num3} is = {avg}')
# Out:
# the avg of 60,70 and 90 is = 73.33333333333333

# %%
print('hello',end=' ') #End Statement
print('Good M')
# Out:
# hello Good M

# %%
print('Egg','Chicken','Paneer',sep='>>>') #Seperator Method
# Out:
# Egg>>>Chicken>>>Paneer
