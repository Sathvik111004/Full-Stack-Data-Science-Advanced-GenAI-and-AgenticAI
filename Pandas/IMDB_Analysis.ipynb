# %%
import pandas as pd

# %%
movies = pd.read_csv("/Users/sathvikgattu/Downloads/IMDB_Rating_Analysis/movie.csv")

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags = pd.read_csv("/Users/sathvikgattu/Downloads/IMDB_Rating_Analysis/tag.csv")

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
ratings = pd.read_csv("/Users/sathvikgattu/Downloads/IMDB_Rating_Analysis/rating.csv")

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
print(movies.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
del ratings['timestamp'] # Deleting Time Stamp
del tags ['timestamp']

# %%
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[0] #Index locations
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# np.float64(3.5255285642993797)

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = ratings['rating']>10
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# np.False_

# %% [markdown]
# Data Cleaning : Handling Missing Data

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any().any() # Checking for Null values
# Out:
# np.False_

# %%
ratings.isnull().any().any()
# Out:
# np.False_

# %%
tags.isnull().any().any() # Missing values found
# Out:
# np.True_

# %%
tags=tags.dropna() # Drops null values

# %%
tags.isnull().any().any() # Now no null values in tags
# Out:
# np.False_

# %% [markdown]
# Data visualization

# %%
import matplotlib as plt

# %%
# %matplotlib inline
ratings.hist(column='rating',figsize=(5,2))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
ratings.boxplot(column='rating', figsize=(5,2))
# Out:
# <Axes: >

# %% [markdown]
# Slicing out Columns

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tags[:10].plot(kind='bar',figsize=(5,2))
# Out:
# <Axes: >
